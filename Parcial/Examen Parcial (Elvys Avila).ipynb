# %%
import numpy as np 
import matplotlib.pyplot as plt 
x=np.random.randn(100)
y=np.random.randn(100)
plt.scatter(x,y,s=40)
plt.show()

# %%
import numpy as np
def PesoMolecular(formula):
    na=np.array(formula)
    pesos=np.array([12.0,1.0,14.0,16.0])
    PM=12*formula[0]+1*formula[1]+14*formula[2]+16*formula[3]
    return PM

# %%
PesoMolecular([1,4,1,2])
# Out:
# 62

# %%
import matplotlib.pyplot as plt
A=3.52
B=-2.85
C=5.16
x=np.linspace(0.1,1,50)
y=A+np.log10(x)*B+C*x**2/2
plt.plot(x,y)
plt.show()

# %%
pH=4.72-np.log10((1-x)/(x))
plt.plot(x,pH)
plt.show()
